# %%
import streamlit as st
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from transformers import pipeline
from transformers import AutoModel

# %%
def getLlamaResponse(input_text, no_words, category):
    llm = CTransformers(model = 'BashitAli/llama-2-7b-chat.ggmlv3.q5_K_M',
                        model_type = 'llama',
                        config={'max_new_tokens': 256,
                                'temperature': 0.01})
    
    ## PromptTemplate
    template = """Write a  {category} on {input_text} in less than {no_words} words"""

    prompt = PromptTemplate(input_variables = ["input_text", "no_words", "category"],
                            template = template)
    
    ## Generate the reponse from the LLama 2 Model
    respone = llm(prompt.format(category=category,input_text=input_text,no_words=no_words))
    print(respone)
    return respone

# %%
input_text = "Effects of global warming"
no_words = "20"
category = "Poem"

print(f'Output from Llama: {getLlamaResponse(input_text, no_words, category)}')
# Out:
# ...
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 11781.75it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 5
#       2 no_words = "20"
#       3 category = "Poem"
# ----> 5 print(f'Output from Llama: {getLlamaResponse(input_text, no_words, category)}')
#
# Cell In[23], line 2, in getLlamaResponse(input_text, no_words, category)
#       1 def getLlamaResponse(input_text, no_words, category):
# ----> 2     llm = CTransformers(model = 'BashitAli/llama-2-7b-chat.ggmlv3.q5_K_M',
#       3                         model_type = 'llama',
#       4                         config={'max_new_tokens': 256,
#       5                                 'temperature': 0.01})
#       7     ## PromptTemplate
#       8     template = """Write a  {category} on {input_text} in less than {no_words} words"""
#
# ...

# %%
from transformers import AutoModelForCausalLM

# Download the pretrained LLM model
model = AutoModelForCausalLM.from_pretrained("BashitAli/llama-2-7b-chat.ggmlv3.q5_K_M")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.conda/envs/llm_env/lib/python3.9/site-packages/transformers/modeling_utils.py:532, in load_state_dict(checkpoint_file, is_quantized)
#     531     weights_only_kwarg = {"weights_only": True} if is_torch_greater_or_equal_than_1_13 else {}
# --> 532     return torch.load(
#     533         checkpoint_file,
#     534         map_location=map_location,
#     535         **weights_only_kwarg,
#     536         **extra_args,
#     537     )
#     538 except Exception as e:
#
# File ~/.conda/envs/llm_env/lib/python3.9/site-packages/torch/serialization.py:1037, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1036 try:
# -> 1037     return _legacy_load(opened_file, map_location, _weights_only_unpickler, **pickle_load_args)
#    1038 except RuntimeError as e:
#
# ...

# %%
import streamlit as st
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from transformers import AutoModelForCausalLM

# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("TheBloke/Llama-2-7B-Chat-GGML")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Load model directly
#       2 from transformers import AutoModel
# ----> 3 model = AutoModel.from_pretrained("TheBloke/Llama-2-7B-Chat-GGML")
#
# File ~/.conda/envs/llm_env/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
# ...

# %%
def getLlamaResponse(input_text, no_words, category):
    llm = CTransformers(model='BashitAli/llama-2-7b-chat.ggmlv3.q5_K_M',
                        model_type='llama',
                        config={'max_new_tokens': 256,
                                'temperature': 0.01})

    template = f"Write a {category} on {input_text} in less than {no_words} words"
    prompt = PromptTemplate(input_variables=["input_text", "no_words", "category"],
                            template=template)

    response = llm(prompt.format(category=category, input_text=input_text, no_words=no_words))
    return response

# %%
input_text = "Effects of global warming"
no_words = "20"
category = "Poem"

response = getLlamaResponse(input_text, no_words, category)
print(f'Output from Llama: {response}')
